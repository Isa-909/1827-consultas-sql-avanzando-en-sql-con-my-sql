# %% [markdown]
# <a href="https://colab.research.google.com/github/Isa-909/1827-consultas-sql-avanzando-en-sql-con-my-sql/blob/main/Copia_de_1_Introducci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #*Encuadre*
#
# ##Objetivo:
#  Adquirir habilidades fundamentales para el desarrollo de aplicaciones y proyectos en Python, lo que les permitirá mejorar su perfil profesional y expandir sus opciones de carrera. Además, este taller busca fomentar la creatividad y la innovación en el ámbito de la programación, incentivando a los participantes a desarrollar soluciones innovadoras y eficientes a través del uso de Python.
#
#  ## Temario:
#
# · Introducción a la lógica de programación
#
# · Tipos de datos y operadores en Python
#
# . Funciones para recibir y mostrar datos
#
# . Funciones condicionales
#
# · Ciclos
#
# . Listas
#
# · Funciones parametrizadas y no parametrizadas
#
# · Uso de librerías
#
# ##Criterios de acreditación:
#
#
# *   Entregar al 100% las actividades propuestas
# *   Obtener un mínimo de 7 como calificación en la evaluación final
# *   Asistencia del 80%

# %% [markdown]
# # **Que podemos hacer con Python?**
# Python es utilizado en múltiples campos industriales y académicos tales como:
#
# * Aprendizaje automático (Machine Learning)
# * Inteligencia Artificial (IA) Big data y Análisis de datos
# * Operaciones matemáticas avanzadas
# * Gráficos en 2D y 3D
# * Visualización, depuración y análisis de datos
# * Programación de apps
# * Desarrollo web
# * Desarrollo de videojuegos
# * Gestión financiera

# %% [markdown]
# ## Redes neuronales

# %%
import tensorflow as tf
import numpy as np
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])
modelo.compile(optimizer=tf.keras.optimizers.Adam(0.1),loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print("Comenzando entrenamiento...")
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado!")
# Out:
# Comenzando entrenamiento...
# Modelo entrenado!

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])

# %%
print("Hagamos una predicción!")
resultado = modelo.predict(250)
print("El resultado es ",resultado," fahrenheit!")

# %%
482
# Out:
# 482

# %%
# Fórmula para pasar de C a F: Cx(9/5)+32
250*9/5+32
# Out:
# 482.0

# %% [markdown]
# ## Adivina el número

# %%
#Juego Adivina el número
import random

intentosRealizados = 0

miNombre = input("¡Hola! ¿Cómo te llamas?")

número = random.randint(1, 20)
print("Bueno, ", miNombre ,", estoy pensando en un número entre 1 y 20.")

while intentosRealizados < 6:
  estimación = int(input("Intenta adivinar."))
  intentosRealizados = intentosRealizados + 1

  if estimación < número:
    print("Tu estimación es muy baja.")
  if estimación > número:
    print("Tu estimación es muy alta.")
  if estimación == número:
    break

if estimación == número:
  print("¡Buen trabajo, ", miNombre,  "! ¡Has adivinado mi número en ",intentosRealizados,"intentos!")

if estimación != número:
    print("Pues no. El número que estaba pensando era ", número)
# Out:
# ¡Hola! ¿Cómo te llamas?Serrano
# Bueno,  Serrano , estoy pensando en un número entre 1 y 20.
# Intenta adivinar.10
# Tu estimación es muy alta.
# Intenta adivinar.5
# Tu estimación es muy baja.
# Intenta adivinar.7
# Tu estimación es muy baja.
# Intenta adivinar.8
# Tu estimación es muy baja.
# Intenta adivinar.9
# ¡Buen trabajo,  Serrano ! ¡Has adivinado mi número en  5 intentos!

# %% [markdown]
# ## Aplicaciones estadísticas

# %%
import pandas as pd
datos = [
  ["Juan", 16, 1.69],
  ["Maria",15,1.60],
  ["Pedro", 17, 1.73]
  ]

df4 = pd.DataFrame(datos, columns=["Nombre", "Edad", "Altura"])
df4
# Out:
#   Nombre  Edad  Altura
# 0   Juan    16    1.69
# 1  Maria    15    1.60
# 2  Pedro    17    1.73

# %%
df4.describe()
# Out:
#        Edad    Altura
# count   3.0  3.000000
# mean   16.0  1.673333
# std     1.0  0.066583
# min    15.0  1.600000
# 25%    15.5  1.645000
# 50%    16.0  1.690000
# 75%    16.5  1.710000
# max    17.0  1.730000

# %% [markdown]
# ## Matemáticas
# ![image.png](data:image/png;base64,...)

# %%
import sympy as sp
x=sp.symbols('x')
y=sp.Function('y')

ED=sp.Eq(2*sp.diff(y(x))-5*y(x),x/3)

# %%
ED
# Out:
# Eq(-5*y(x) + 2*Derivative(y(x), x), x/3)

# %%
sp.dsolve(ED,y(x))
# Out:
# Eq(y(x), C1*exp(5*x/2) - x/15 - 2/75)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Introducción**
# ##¿Para que sirve una computadora?
#
# ##¿Han escuchado sobre el algoritmo?
#
# **Algoritmo** es un conjunto de acciones o pasos finitos, ordenados de forma lógica y que se utilizan para resolver un problema o para obtener un resultado.
#
# Ejemplo **Vestirse**: 1. Te despiertas 2. Te lavas la cara 3. Escoges la ropa que te vas a poner 4. Escoges los zapatos 5. Te quitas la pijama 6. Te pones el pantalón 7. Te pones la playera 8. Te pones las calcetas 9. Luego los zapatos 10.FIN.
#
# Desarrollar el algoritmo para:
# 1. Aplicar un examen
# 2. Subir calificaciones a SAES
# 3. Preparar una exposición
#
# ## Diagrama de flujo
# Es una representación gráfica que muestra las variaciones y relaciones de una serie de acciones con un objetivo en común.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Elaborar el algoritmo y un diagrama de flujo para:** (usar lucidchart)
#
#
# 1.Preparar un huevo
#
# 2.Calcular el área y perimetro de un rectángulo

# %% [markdown]
# # **Lenguajes de programación**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **¿Por qué Python?**
# Python se puede utilizar en infinidad de proyectos y aplicaciones tales como:Aprendizaje automático (Machine Learning), Inteligencia Artificial (IA), Big data y Análisis de datos, Operaciones matemáticas, Visualización de datos, Programación de apps, Desarrollo web, Desarrollo de videojuegos, Gestión financiera.

# %% [markdown]
# ## Ventajas de python
#
# Grátis y de código abierto
#
# Baja curva de aprendizaje (fácil e intuitivo)
#
# Multiplataforma(Linux, Windows, UNIX, Mac OS)
#
# Lenguaje interpretado
#
# Multiparadigma (POO, procedimientos, etc)

# %% [markdown]
# ## Diferencia entre intérprete y compilador.
# Un **intérprete** es un programa que ejecuta directamente las instrucciones escritas en un lenguaje de programación dado.
# Un **compilador** es un programa que transforma el código fuente de un programa a su equivalente en otro lenguaje de programación de más bajo nivel.

# %% [markdown]
# **Entorno de desarrollo**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# google colab

# %% [markdown]
# # Tipos de datos y variables
# Tenemos datos de tipo entero (int), decimal (float), caracteres (str), boleanos y listas.
#
# Las variables se declaran poniendo el nombre de la misma y un igual.

# %%
# Ejemplo de varíable entera tipo int
y=2
y+5
# Out:
# 7

# %%
# Ejemplo de flotante
x = 3.5
x-4
# Out:
# -0.5

# %%
edad_de_la_persona  = 40
edad_de_la_persona / 2
# Out:
# 20.0

# %%
#Operaciones básicas

# %%
x**y
# Out:
# 12.25

# %%
#Variable tipo caracter
nombre = 'Serrano'
nombre
# Out:
# 'Serrano'

# %%
b=10
c=-5
a=12
d=a+b+c
print(d) #LA FUNCIÓN PRINT NO LLEVA IGUAL
# Out:
# 17

# %%
txt = 'curso python' # TODO TEXTO VA EN COMILLAS YA SEAN DOBLES O SIMPLES
print(txt)
# Out:
# curso python

# %%
precio = 15.6   #esta es una variable flotante
descuento = 3
precio_final = precio - descuento   #este es la manera en que se calculó el precio final
print(precio_final)
# Out:
# 12.6

# %% [markdown]
# ## Variables booleanas

# %%
#Ejemplo de operadores relacionales (<,>,,<=,>=,=,!=)
3>4
# Out:
# False

# %%
4 <= 5
# Out:
# True

# %%
#Ejemplo de operadores lógicos (and, or, not)
# Out:
# False

# %%
'''


gdg
sava
gasfas
fasff


'''
# Out:
# False

# %% [markdown]
# #Funciones prestablecidas
# Las dos principales funciones son print e input. **Print** puede mandar a imprimir en pantalla textos que deben de ir entre comillas, números, varaibles y también operaciones.
# **Input** imprime texto en pantalla pero principalmente recibe datos del usuario y siempre debe ir ligado a una variable, por default recibe el dato en forma de texto.
#
# La función **print** es capaz de mostrar en pantalla textos, variables, operaciones etc
#
# La función print puede escribirse como print(f"texto, {variable}, texto, {operación}, texto") de modo que no se requieren tantos elemento para la separación de datos.

# %% [markdown]
# **Ejemplos**
#
# +Hacer el hola mundo
#
# +Guardar hola mundo en una variable y mostrarla en pantalla
#
# +Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética
# ![image.png](data:image/png;base64,...)
#
# +Guardar 9 en una variable y mostrar su raiz con un texto
#
# +Crear un programa el cual asigne tu nombre en una variable, el año de nacimiento en otra y muestre en pantalla un saludo, el nombre y la edad.

# %%
print('Me gustan las tlayudas oaxaqueñas!')
# Out:
# Me gustan las tlayudas oaxaqueñas!

# %%
comida = 'Tlayuda oaxaqueña'
print(comida)
# Out:
# Tlayuda oaxaqueña

# %%
((3+2)/(2*5))**2
# Out:
# 0.25

# %%
numerador = 3+2
denominador = 2*5
valor = numerador / denominador
valor**2
# Out:
# 0.25

# %%
x = (3+2)/(2*5)
print(x**2)
# Out:
# 0.25

# %%
nombre = 'serrano'
edad = 40
print('Hola', nombre, 'tienes', edad, 'años')
print(f'Hola {nombre} tienes {edad} años')
# Out:
# Hola serrano tienes 40 años
# Hola serrano tienes 40 años

# %%
print(2*5)
print('hola')
print(3*7)
# Out:
# 10
# hola
# 21

# %%
a = 30
print("La raiz de:", a, "es:", a**.5)
print(f'La raiz de: {a} es: {a**.5 : .5f} ')
# Out:
# La raiz de: 30 es: 5.477225575051661
# La raiz de: 30 es:  5.47723

# %%
#Programa que saluda y calcula la edad
nombre = "Serrano"
año = 1985    #año de nacimiento
print(f"Hola {nombre} naciste en el año {año} y tienes {2025-año} años")
print("Hola", nombre, "naciste en el año", año, "y tienes", 2025-año, "años")
# Out:
# Hola Serrano naciste en el año 1985 y tienes 40 años
# Hola Serrano naciste en el año 1985 y tienes 40 años

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicios

# %% [markdown]
# 1. Almacenar en dos variables el 5 y el 7, realizar y mostrar la suma entre ellos.
# 2. Almacenar el nombre de un producto y su precio en dos variables, posteriormente mostrarlas en pantalla.
# 3. Crear la variable x=3, y=5, realizar las siguientes operaciones y mostrar en pantalla el resultado:
# * x=x+y
# * y=2x-y
# * x^2 +y^2
# 4. Aplicar todos los operadores relacionales a las variables a=2 y b=7 y mostrar los resultados con la función print.
# 5. Escriba un programa en el cual contenga las variables a='Pedro' y b='pedro', ejecute print(a==b), print(a=b) y comente cual es su conclusión.
# 6. Crear las variables precio=7.5 y cantidad=400 mediantes las cuales guardar en la variable ingreso su valor correspondiente.
# 7. Almacenar las sigueintes calificaciones en variables y calcular el promedio: 7, 6.5, 8.4, 9, 4
# 8. Comente que sucede cuando a='5' y b='3' y calculamos a+b
# 9. Escriba nombre='Pedro', x=200, y=15.4 y ejecute en celdas separadas: type(nombre), type(x) y type(y). Cuales son sus conclusiones.
# 10. Obtenga la raiz cuadrada de 10.

# %%
producto = 'Bimbo'
precio = 55
print(f'El producto {producto} tiene un precio de {precio}')
# Out:
# El producto Bimbo tiene un precio de 55

# %%
x = 3
y = 5
x = x + y
y = 2*x + y
x**2+y**2
# Out:
# 505

# %%
a = 2
b = 7
a<b
# Out:
# True

# %%
a = 'Pedro'
b = 'pedro'
a = b
print(a)
# Out:
# pedro

# %%
P = 7.5
Q = 400
I = P * Q
print(I)
# Out:
# 3000.0

# %%
print(10**.con)

# %%
# 1. Almacenar en dos variables el 5 y el 7, realizar y mostrar la suma entre ellos.
num1 = 5
num2 = 7
suma = num1 + num2
print(f"La suma de {num1} y {num2} es: {suma}")

# 2. Almacenar el nombre de un producto y su precio en dos variables, posteriormente mostrarlas en pantalla.
nombre_producto = "Laptop"
precio_producto = 1200.50
print(f"Producto: {nombre_producto}, Precio: ${precio_producto}")

# 3. Crear la variable x=3, y=5, realizar las siguientes operaciones y mostrar en pantalla el resultado:
x = 3
y = 5
print(f"Valores iniciales: x={x}, y={y}")

x = x + y
print(f"Después de x = x + y, el valor de x es: {x}")

y = 2 * x - y
print(f"Después de y = 2 * x - y, el valor de y es: {y}")

resultado_cuadrados = x**2 + y**2
print(f"El resultado de x^2 + y^2 es: {resultado_cuadrados}")

# 4. Aplicar todos los operadores relacionales a las variables a=2 y b=7 y mostrar los resultados con la función print.
a_rel = 2
b_rel = 7
print(f"Para a={a_rel} y b={b_rel}:")
print(f"a == b: {a_rel == b_rel}")
print(f"a != b: {a_rel != b_rel}")
print(f"a < b: {a_rel < b_rel}")
print(f"a > b: {a_rel > b_rel}")
print(f"a <= b: {a_rel <= b_rel}")
print(f"a >= b: {a_rel >= b_rel}")

# 5. Escriba un programa en el cual contenga las variables a='Pedro' y b='pedro', ejecute print(a==b), print(a=b) y comente cual es su conclusión.
a_str = 'Pedro'
b_str = 'pedro'
print(f"Para a='{a_str}' y b='{b_str}':")
print(f"print(a_str == b_str): {a_str == b_str}")
# print(a_str = b_str) # Esta línea generaría un error de sintaxis en Python porque '=' es para asignación, no para comparación.
# Para mostrar la asignación y su efecto, se hace lo siguiente:
print("Al ejecutar 'a_str = b_str' se realiza una asignación, no una comparación. Esto cambia el valor de 'a_str' a 'pedro'.")
a_str = b_str
print(f"Después de a_str = b_str, print(a_str): {a_str}")


# 6. Crear las variables precio=7.5 y cantidad=400 mediantes las cuales guardar en la variable ingreso su valor correspondiente.
precio = 7.5
cantidad = 400
ingreso = precio * cantidad
print(f"Para precio={precio} y cantidad={cantidad}, el ingreso es: {ingreso}")

# 7. Almacenar las siguientes calificaciones en variables y calcular el promedio: 7, 6.5, 8.4, 9, 4
cal1 = 7
cal2 = 6.5
cal3 = 8.4
cal4 = 9
cal5 = 4
promedio = (cal1 + cal2 + cal3 + cal4 + cal5) / 5
print(f"Las calificaciones son: {cal1}, {cal2}, {cal3}, {cal4}, {cal5}")
print(f"El promedio de las calificaciones es: {promedio}")

# 8. Comente que sucede cuando a='5' y b='3' y calculamos a+b
a_com = '5'
b_com = '3'
print(f"Si a='{a_com}' y b='{b_com}', la operación a + b resulta en: {a_com + b_com}")
print("Cuando 'a' y 'b' son cadenas de texto (strings), el operador '+' realiza una concatenación, es decir, une las cadenas. Por lo tanto, '5' + '3' da como resultado '53' y no la suma numérica de 8.")

# 9. Escriba nombre='Pedro', x=200, y=15.4 y ejecute en celdas separadas: type(nombre), type(x) y type(y). Cuales son sus conclusiones.
nombre_type = 'Pedro'
x_type = 200
y_type = 15.4

print(f"Para nombre='{nombre_type}', type(nombre) es: {type(nombre_type)}")
print(f"Para x={x_type}, type(x) es: {type(x_type)}")
print(f"Para y={y_type}, type(y) es: {type(y_type)}")
print("Conclusión: La función 'type()' nos permite conocer el tipo de dato de una variable. 'Pedro' es una cadena de texto (str), 200 es un número entero (int) y 15.4 es un número de punto flotante (float). Python infiere automáticamente el tipo de dato según el valor asignado.")

# 10. Obtenga la raiz cuadrada de 10.
import math
raiz_cuadrada_10 = math.sqrt(10)
print(f"La raíz cuadrada de 10 es: {raiz_cuadrada_10}")
# Out:
# La suma de 5 y 7 es: 12
# Producto: Laptop, Precio: $1200.5
# Valores iniciales: x=3, y=5
# Después de x = x + y, el valor de x es: 8
# Después de y = 2 * x - y, el valor de y es: 11
# El resultado de x^2 + y^2 es: 185
# Para a=2 y b=7:
# a == b: False
# a != b: True
# a < b: True
# a > b: False
# a <= b: True
# a >= b: False
# Para a='Pedro' y b='pedro':
# print(a_str == b_str): False
# Al ejecutar 'a_str = b_str' se realiza una asignación, no una comparación. Esto cambia el valor de 'a_str' a 'pedro'.
# Después de a_str = b_str, print(a_str): pedro
# Para precio=7.5 y cantidad=400, el ingreso es: 3000.0
# Las calificaciones son: 7, 6.5, 8.4, 9, 4
# El promedio de las calificaciones es: 6.9799999999999995
# Si a='5' y b='3', la operación a + b resulta en: 53
# Cuando 'a' y 'b' son cadenas de texto (strings), el operador '+' realiza una concatenación, es decir, une las cadenas. Por lo tanto, '5' + '3' da como resultado '53' y no la suma numérica de 8.
# ...
