# %% [markdown]
# <a href="https://colab.research.google.com/github/Isa-909/1827-consultas-sql-avanzando-en-sql-con-my-sql/blob/main/3_Ejercicios_If.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Ejemplos chidos!**
#
# Programa que grafica mediante número aleatorios un mapa de calor

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
data = np.random.random((6, 12))

# Etiquetas
xlabs = ["ENERO", "FEBRERO", "MARZO", "ABRIL",
         "MAYO", "JUNIO", "JULIO", "AGOSTO","SEPTIEMBRE",
         "OCTUBRE","NOVIEMBRE", "DICIEMBRE"]
ylabs = ["LIMA", "PIURA", "AREQUIPA", "CUSCO",
        "PUNO", "ICA"]

# Mapa de calor
fig, ax = plt.subplots()
im=ax.imshow(data)

# Agregar las etiquetas
ax.set_xticks(np.arange(len(xlabs)), labels = xlabs)
ax.set_yticks(np.arange(len(ylabs)), labels = ylabs)

# Agregar la leyenda
cbar = ax.figure.colorbar(im, ax = ax)
cbar.ax.set_ylabel("Leyenda", rotation = -90, va = "bottom")

# AGREGAR LOS VALORES A LA GRAFICA
for i in range(len(ylabs)):
    for j in range(len(xlabs)):
        text = ax.text(j, i, round(data[i, j],1),ha="center", va="center", color="white")

plt.setp(ax.get_xticklabels(), rotation = 40, ha = "right", rotation_mode = "anchor")

plt.title("MAPA DE CALOR - CORONAVIRUS (2022)")
plt.show()

# %% [markdown]
# #Condicional IF
#
# El operador if se utiliza para determinar alternativas dentro del programa o llevar a cabo validaciones, en caso de que algo suceda se realiza una acción, en caso contrario se puede ejecutar una acción distinta.
#
# Para la toma de decisiones podemos hacer uso de los operadores relacionales, lógicos y las variables booleanas verdadero y falso mediante las  palabras reservadas True y False.
#
# La sintaxis de una condicional if es:
#
# if CONDICIÓN:
#
#    INSTRUCCIÓN
#
# Si se cumple con la CONDICIÓN, esto es si su valor es True, entonces se ejecuta la INSTRUCCIÓN, o el conjunto de instrucciones, la cual debe llevar siempre una sangría. Todo lo que esté en sangría se considerará como parte del if y se ejecutará siempre y cuando se cumpla con la CONDICIÓN.

# %%
a = 1
if a > 3 :
  print(f'El valor de a es mayor que 3')
  print('Hola')
  print(a)
  b = input('dime tu nombre ')
  print(b)
print('fin del programa')
# Out:
# fin del programa

# %%
a > 3
# Out:
# False

# %%
a=5
if True:
  print('hola')

print('fuera del if')
# Out:
# hola
# fuera del if

# %%
5==5
# Out:
# True

# %%
#Elaborar un programa que pregunte al usuario si le gusta el huevito con catsup,
#en caso de responder si, lo felicitamos
resp = input('Te gusta el huevito con catsup? si/no ').lower()
if resp == 'si' or resp == 'simon' or resp == 'claro' or resp == 'por supuesto' or resp == 'afirmativo':
  print(f'Felicidades eres de los mios')
else:
  print('Que te pasa? te estas perdiendo de lo bueno! ')
print('fin del programa')
# Out:
# Te gusta el huevito con catsup? si/no no
# Que te pasa? te estas perdiendo de lo bueno!
# fin del programa

# %%
#Pregunta la edad e indica si es mayor o menor de edad
edad = int(input('dime tu edad '))
if edad >= 18:
  print('Eres mayor de edad')
else:
  print('Eres menor de edad')
print('Fin del programa')
# Out:
# dime tu edad 13
# Eres menor de edad
# Fin del programa

# %% [markdown]
# Operadores lógicos
# y   and
# o    or

# %%
#Elaborar un programa que pregunte al usuario si es un robot, si lo es no puede entrar
resp = input('Eres un robot? si/no ').lower()
if resp == 'si':
  print('No puedes entrar terminator')
else:
  print('Si puedes entrar')
print('fin del programa')
# Out:
# Eres un robot? si/no nana pancha
# Si puedes entrar
# fin del programa

# %%
resp = input('Eres un robot? si/no ').lower()
if resp != 'no':
  print('no puedes entrar')
else:
  print('si puedes entrar')
# Out:
# Eres un robot? si/no no
# si puedes entrar

# %%
#Elaborar un programa que pida un número positivo o cero y valide que efecctivamente lo sea
num = float(input('Dame un numero '))
if num >= 0 :
  print('El numero que ingresaste es mayor o igual a cero')
else:
  print('El numero que ingresaste es menor a cero')
# Out:
# Dame un numero cuatro
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-6ceecbd7e03e> in <cell line: 0>()
#       1 #Elaborar un programa que pida un número positivo o cero y valide que efecctivamente lo sea
# ----> 2 num = float(input('Dame un numero '))
#       3 if num >= 0 :
#       4   print('El numero que ingresaste es mayor o igual a cero')
#       5 else:
#
# ValueError: could not convert string to float: 'cuatro'

# %%
#Elaborar un programa que pregunte la edad,
#si es mayor de edad le dice que ya es un adulto
edad = int(input('Dime tu edad '))
if edad >= 18:
  print('Eres mayor de edad')
else:
  print('eres menor de edad ')
# Out:
# Dime tu edad 9
# eres menor de edad

# %% [markdown]
# #IF / ELSE
#
# En caso de que el if no se cumpla podemos darle una instrucción a Python para realizar otra instrucción mediante la palabra reservada else la cual lleva una o varias instrucciones que se ejecutarán siempre y cuando la condición del if no se haya cumplido, dichas instrucciones deben llevar sangría para indicar que se encuentran dentro del else. El operador else siempre termina con dos puntos.
#
# Un if puede o no tener un else, en caso contrario no podemos tener un else sin que antes se encuentre un if, no tiene sentido.
#
# if condición:
#
#   ...
#
#   ...
#
#   ...
#
# else:
#
#
#   ...
#
#   ...

# %%
#Preguntar al usuario si tiene materias reprobadas, dependiendo de la
#respuesta decirle que es alumno regular o irregular
resp = input('Tienes materias reprobadas? ')
if resp == 'no':
  print('Eres regular ')
else:
  print('eres irregular')
# Out:
# Tienes materias reprobadas? no
# Eres regular

# %%
#Elaborar un programa que pide la calificación y te dice si aptobaste, reprobaste
calif = float(input('Dime tu calif '))
if 6 <= calif <= 10 :
  print('Aprobado')
elif 0 <= calif < 6:
  print('Reprobado')
else:
  print('error de calif')

print('fin del programa')
# Out:
# Dime tu calif 4
# Reprobado
# fin del programa

# %%
#Elaborar programa que pregunte al alumno nombre y si el IPN es su primera opción.
#Si responde afirmativamente lo felicitamos, en caso contrario le decimos que se cambie de escuela.
resp = input('El ipn fue tu primera opción? ')
nombre = input('dime tu nombre ')
if resp == 'si':
  print(f'{nombre} felicidades!')
else:
  print(f'{nombre} cambiate de escuela ')
# Out:
# El ipn fue ti primera opción? no
# dime tu nombre serrano
# serrano cambiate de escuela

# %%
#Escribir un programa que almacene la cadena de caracteres contraseña en una variable,
#pregunte al usuario por la contraseña para poder acceder.

# %%
#Programa que pregunta al ususario si desea realizar una suma o una resta
#entre dos número proporcionados por el.
x = float(input('Dame un num '))
y = float(input('Dame un num '))
resp = input('dime si queieres suma o resta ').lower()
if resp == 'suma':
  print(f'La suma de los num es {x+y}')
if resp == 'resta':
  print(f'{x-y}')
print('fin')
# Out:
# Dame un num 5
# Dame un num 4
# dime si queieres suma o resta  suma
# fin

# %%
'''En MX la figura de RESICO exige que el contribuyente tenga ingresos menores
a 3.5 millones de pesos a nuales, preguntar al usuario su ingreso y determinar
si es o no RESICO.'''
ingreso  = float(input('Dime tu ingreso anual '))
if ingreso >= 3500000:
  print('No eres resico')
else:
  print('Eres resico')
# Out:
# Dime tu ingreso anual 4000000
# No eres resico

# %%
#Escribir un programa que pida al usuario dos números y muestre en pantalla su división.
#Si el divisor es cero el programa debe mostrar un error y continuar.
a = float(input('dame un numero '))
b = float(input('dame un numero '))
'''if b == 0 :
  print('No existen las div entre cero')
else:
  print(a/b)'''

if b != 0 :
  print(a/b)
else:
  print('No existen las div entre cero')
# Out:
# dame un numero 3
# dame un numero 0
# No existen las div entre cero

# %%
5'''El programa le pregunta al usuario si desea calcular área
o perímetro de un rectángulo. Solicita base y altura y
realiza la operación correspondiente.'''

# %%
resp = input('Dime si tienes BTC si/no ').lower()
if resp == 'si':
  print('Seguro ya te hiciste de mucha lana ')
  btc = float(input('Dime cuanto btc tienes '))
  print(f'wooow {btc} bitcoin es muchisimo')
  print(f'Tu btc es igual a ${btc*2000000} pesos')
elif resp == 'no':
  print('Invierte ahora ')
  mxn = float(input('Dime cuanto podrías invertir '))
  print(f'Con {mxn} no te alcanza par nada')
else:
  print('Todo menso')
# Out:
# Dime si tienes BTC si/no si
# Seguro ya te hiciste de mucha lana
# Dime cuanto btc tienes 3
# wooow 3.0 es muchisimo
# Tu btc es igual a 6000000.0 pesos

# %%
#Escribir un programa que pida al usuario un número entero y muestre por
#pantalla si es par o impar.
# tip: operación módulo
# Out:
# 1

# %% [markdown]
# #ELIF
# Se usa para verificar más de una condición, y para detener cuando se encuentra la primera declaración verdadera.
#
# Es bastante útil para cunado requerimos insertar una serie de condiciones mutuamente excluyentes, en el caso de que alguna de ellas resulte verdadera, ya no deberá ser necesario validar el resto. Si se usan únicamente ifs para resolver el problema planteado, en caso de que alguna de las condiciones resulte verdadera, python continuará validando las demás aún cuando sabemos que nunca se van a cumplir, generando un código ineficiente.
#
# No debes usar else sin un if precedente.
# Else siempre es la última rama de la cascada , independientemente de si has usado elif o no.
# Else es una parte opcional de la cascada, y puede omitirse.
# Si hay una rama else en la cascada, solo se ejecuta una de todas las ramas.
# Si no hay una rama else, es posible que no se ejecute ninguna de las opciones disponibles.

# %%
#TERMIAN LA CALULADORA
resp = input('dime la operación a realizar ')
a = float(input('dame el valor de a '))
b = float(input('dame el valor de a '))
if resp == 'suma':
  print(a+b)
elif resp == 'resta':
  print(a-b)
elif resp == 'mult':
  print(a*b)
elif resp == 'div':
  print(a/b)
else:
  print('operación no valida')
# Out:
# dime la operación a realizar suma
# dame el valor de a 3
# dame el valor de a 4
# 7.0

# %%
#Recibir dos números del usuario y determinar cual de ellos es mayor.
# Out:
# dame un entero 1
# dame otro 1
# los numeros son iguales

# %%
'''Pide la edad, si tiene menos que 10 probablemente está estudiando primaria
si tiene menos que 20 probablemente estudia medio superior
si tiene menos de 30 probablemente está trabajando
si tiene mas de 30 ponemos fuera de rango'''

edad = int(input('Dime tu edad '))
if 0 <= edad <= 10 :
  print('Seguro estás en la primaria')
  trabajas = input('Oye, trabajas? ')
  if trabajas == 'si':
    print('mete tu denuncia al dif')
    preg2 = input('En el campo o en la ciudad? ')
    if preg2 == 'campo':
      print('...')
    else:
      print('.....')
  else:
    print('echale ganas a la escuela')
elif 10 < edad <= 20 :
  print('Estás en la prepa')
  preg3 = input('Has probado tabaco o alcohol? ')
  if preg3 == 'si':
    print('NO hagas eso chavo')
  else:
    preg4 = input('Has probado drogas ilegales ')
    if preg4 == 'si':
      print('Eso no es correcto')
    else:
      print('muy bien')
elif 20 < edad <= 30 :
  print('Estás trabajando')
elif edad > 30:
  print('fuera de rango')
elif edad < 0 :
  print('todo menso')
# Out:
# Dime tu edad 15
# Estás en la prepa
# Has probado tabaco o alcohol? no
# Has probado drogas ilegales no
# muy bien

# %%
'''Si vende menos de 1000 pesos es despedido
Si vende entre 1000 y 5000 está a prueba
Si vende mas 5000 a 10,000 pesos tiene un bono del 5%
mas de 10,000 en adelante el bono es de 10%'''
# Out:
# Dime cuanto vendiste 14000
# Te ganaste un bono de: 1400.0

# %%
'''Programa que recibe el precio de un producto, la cantidad
vendida y el egreso total. determinar si el beneficio de la
empresa se encuentra en pérdidas, está en el punto de equilibrio
o está generando ganancias. Donde:
B=I-E   I=PQ    E=cto   B=PQ-E
B:beneficio   I:ingreso   E:egreso    P:precio   Q: cantidad'''

# %%
#Elaborar calculadora con 4 operaciones básicas

# %% [markdown]
# #If Anidados
#
# Podemos generar programas que contengan múltiples condicionales, por ejemplo ¿tengo ganas de salir? en caso afirmativo ¿el día está nublado? en caso afirmativo ¿me llevo impermeable?. A este tipo de estructura se le denomina if anidados, esto es uno o varios ifs dentro de otro if.
#
# También se denomina como cascada de ifs y pueden o no terminar con un else.

# %%
#Crear el programa de salir a la calle, verificar si está nublado, si lo está llevar impermeable, si no lleva se va a
#enfermar, si no está nublado llevar botella de agua

salir = input('Vas a salir? si/no ')
if salir == 'si':
  nublado = input('Está nublado? si/no ')
  if nublado == 'si':
    imper = input('Llevas impermeable? si/no ')
    if imper == 'si':
      print('Bien hecho chato!')
    else:
      print('Te vas a enfermar')
  else:
    print('Lleva una botella de agua para que no andes comprando, no seas sabandija con el medio ambiente y tu economía')

else:
  print('Ve la serie en netflix OA ')
# Out:
# Vas a salir? si/no si
# Está nublado? si/no no
# Lleva una botella de agua para que no andes comprando, no seas sabandija con el medio ambiente y tu economía

# %%
'''Escribir un programa que pregunte al usuario su edad y su nombre,
si es mayor de edad le preguntamos si trabaja, si lo hace lo felicitamos,
en caso contratrio lo regañamos. Si es menor de edad
le decimos que se ponga a estudiar.'''

# %%
'''Pregunta edad, si es mayor de edad pregunta si votó, si es afirmativo
pregunta por quién, si es negativo lo regaña; pero si es menor de edad
preugunta si estudia, si es afirmativo le pregunta donde, si es negativo
lo regaña'''

# %%
'''Pregunta si le gustan las series, caso afirmativo pregunta si en netflix
caso afirmativo pregunta si ya vió Stranger Things. Si no es en NEtflix pregunta
si en Amazon, en caso afirmativo dice OK, yo no lo veo, soy pobre, en caso negativo
le dice, solo tengo Netflix. Si no le gustan las series responde con un MMM OK.'''

# %%
'''La pizzería Bella Napoli ofrece pizzas vegetarianas y no vegetarianas a sus clientes.
Los ingredientes para cada tipo de pizza aparecen a continuación:
Ingredientes vegetarianos: Pimiento y tofu.
Ingredientes no vegetarianos: Peperoni, Jamón y Salmón.
Escribir un programa que pregunte al usuario si quiere una pizza vegetariana o no,
y en función de su respuesta le muestre un menú con los ingredientes disponibles para que elija.
Solo se puede eligir un ingrediente además de queso y el tomate que están en todas la pizzas.
Al final se debe mostrar por pantalla la pizza elegida  y todos los ingredientes que lleva.'''

# %%
''' Solicita el precio y nombre de un producto, pregunta si lo va a comprar, pregunta cuantas unidades va a comprar,
si compra mas de 5 le damos 10% de descuento, si compra mas de 10 le damos 15% de descuento.
si o compra le decimos chismoso de precios'''

prod = input('dame el nombre del producto ')
precio = float(input('dime el precio '))
compra = input('Vas a querer?si/no ')
if compra == 'si':
  q = int(input('Cuantas vas a lelvar? '))
  if  0 < q <= 5:
    print(f'Vas a pagar {precio*q}')
  elif 5 < q <= 10:
    print(f'Vas a pagar {precio*q*.9}')
  elif q > 10:
    print(f'Vas a pagar {precio*q*.85}')
  else:
    print('Todo menso')
else:
  print('No ande de chismoso!')
# Out:
# dame el nombre del producto bimbo
# dime el precio 55
# Vas a querer?si/no si
# Cuantas vas a lelvar? -4
# Todo menso

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicios
# 1. Recibir dos números e indicar cual de ellos es mayor
# 2. Elaborar un programa que calcule áreas y perímetros de cuadrados preguntando al usuario si quiere área o perímetro.
# 3. Escribir un programa que pregunte al usuario su edad y muestre por pantalla si es mayor de edad o no.
# 4. Escribir un programa que pida al usuario dos números y muestre por pantalla su división. Si el divisor es cero el programa debe mostrar un error.
# 5. Programa que recibe el precio de un producto, la cantidad vendida y el egreso total. Determinar si el beneficio de la empresa se encuentra en pérdidas, está en el punto de equilibrio o está generando ganancias.
# 6. Elaborar un programa que determine si el alumno se encuentra en situación irregular abajo de 6, regular entre 6 y 9.9 y de excelencia si sacó 10.
# 7. Escribir un programa que pida al usuario un número entero y muestre por pantalla si es par o impar.
# 8. Elaborar un programa que reciba el volumen de ventas y el nombre del vendedor. Si vende menos de 1000 pesos es despedido.Si vende entre 1000 y 5000 está a prueba. Si vende de 5000 a 10,000 pesos tiene un bono del 5%. De 10,000 en adelante el bono es de 10%
# 9. Escribir un programa que pregunte al usuario su edad y muestre por pantalla si es mayor de edad o no. Si tiene menos de 10 años indicar que es un niño, entre 18 y 29 joven, entre 30 y 59 adulto, más de 50 es adulto mayor. Si ingresa una edad inválida mandar mensaje de error.
# 10. Recibir 3 números y acomodarlos en orden descendente con ifs
